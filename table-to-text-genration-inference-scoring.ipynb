# %%
import pandas as pd
df=pd.read_csv("/kaggle/input/table-to-text-generation-dataset-google-totto/totto_data/tablesWithTagDev.csv")

# %%
len(df)
# Out:
# 7700

# %%
MAXLENI=400
MAXLENO=200

# %%
from transformers import T5Tokenizer
from transformers import T5ForConditionalGeneration
from transformers import AdamW, WarmUp, get_linear_schedule_with_warmup
from tqdm.notebook import tqdm
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import os
import time
import copy
import numpy
import matplotlib.pyplot as plt

# %%
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
tokenizer = T5Tokenizer.from_pretrained("t5-base")
model=torch.load("/kaggle/input/table-to-text-generation-utils/T5Epoch 7", map_location=device)
# Out:
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.39M [00:00<?, ?B/s]

# %%
special_tokens_dict = {'pad_token': '<pad>', 'bos_token': '<bos>', 'eos_token': '<eos>', 
                       'additional_special_tokens': ['<PAGESTART>', '<PAGEEND>', '<SECTIONSTART>', '<SECTIONEND>',
                                                     '<TABLESTART>','<TABLEEND>','<CELLSTART>','<CELLEND>','<COLHEADERSTART>',
                                                     '<COLHEADEREND>','<ROWHEADERSTART>','<ROWHEADEREND>']}

num_added_toks = tokenizer.add_special_tokens(special_tokens_dict)

print('We have added', num_added_toks, 'tokens')
model.encoder.resize_token_embeddings(len(tokenizer))
model.decoder.resize_token_embeddings(len(tokenizer))
# Out:
# We have added 14 tokens
# Embedding(32114, 768)

# %%
class tottodataset(Dataset):
  def __init__(self,df,tokenizer):
    self.sentence=df['sentence']
    self.table=df['table']
    self.tokenizer=tokenizer

  def __len__(self):
    return len(self.sentence)
  
  def __getitem__(self,idx):
    inp=(self.table[idx]+'</s>').replace("<page_title>", "<PAGESTART>").replace("</page_title>", "<PAGEEND>") \
                                    .replace("<section_title>", "<SECTIONSTART>").replace("</section_title>", "<SECTIONEND>") \
                                    .replace("<table>", "<TABLESTART>").replace("</table>", "<TABLEEND>") \
                                    .replace("<cell>", "<CELLSTART>").replace("</cell>", "<CELLEND>") \
                                    .replace("<col_header>", "<COLHEADERSTART>").replace("</col_header>", "<COLHEADEREND>") \
                                    .replace("<row_header>", "<ROWHEADERSTART>").replace("</row_header>", "<ROWHEADEREND>")
    out=self.sentence[idx]+'</s>'
    inp_tokens=self.tokenizer.encode_plus(inp, padding="max_length", max_length=MAXLENI, truncation=True)
    out_tokens=self.tokenizer.encode_plus(out, padding="max_length", max_length=MAXLENO, truncation=True)
    inp_id=inp_tokens.input_ids
    out_id=out_tokens.input_ids
    inp_mask=inp_tokens.attention_mask
    out_mask=out_tokens.attention_mask
    labels=out_tokens.input_ids.copy()
    labels=[-100  if x==self.tokenizer.pad_token_id else x for x in labels]

    return {
        "table_text":inp,
        "sentence":out,
        "input_ids":torch.tensor(inp_id, dtype=torch.long),
        "input_attention_mask":torch.tensor(inp_mask, dtype=torch.long),
        "decoder_input_ids":torch.tensor(out_id, dtype=torch.long),
        "decoder_attention_mask":torch.tensor(out_mask, dtype=torch.long),
        "labels":torch.tensor(labels, dtype=torch.long)
    }

# %%
test_dataset=tottodataset(df,tokenizer)

test_dataloader=DataLoader(test_dataset,
                            batch_size=64,
                            num_workers=2,
                            shuffle=False)

# %%
model.to(device)
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 768)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32114, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32114, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=32128, bias=False)
# )

# %%
# !nvidia-smi
# Out:
# Mon Aug 23 15:38:59 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.119.04   Driver Version: 450.119.04   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    32W / 250W |   1981MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
test_iterator=iter(test_dataloader)

# %%
test_batch=next(test_iterator)

# %%
generation_output = model.generate(test_batch['input_ids'].to(device), return_dict_in_generate=True, output_scores=True)

# %%
generation_output["sequences"]
# Out:
# tensor([[    0,  4173,  7780,  ...,   552,   507,  4581],
#         [    0,    86,  5123,  ...,  2129,     6,    11],
#         [    0, 12833,   141,  ...,     0,     0,     0],
#         ...,
#         [    0,  1184,    51,  ...,    52,     7,    10],
#         [    0,  3037,  3233,  ...,     6, 12035,     6],
#         [    0,    37,  1348,  ...,    16,  6156,     9]], device='cuda:0')

# %%
expected=test_batch["sentence"][0]
predicted=tokenizer.decode(generation_output["sequences"][0],skip_special_tokens=True)

# %%
print(f"Expected Sentence: {expected}")
print(f"Predicted Sentence: {predicted}")
# Out:
# Expected Sentence: Daniel Henry Chamberlain was the 76th Governor of South Carolina from 1874.</s>
# Predicted Sentence: Daniel Henry Chamberlain was the 76th Governor of South Carolina, serving until 1874

# %%
# !nvidia-smi
# Out:
# Mon Aug 23 15:39:03 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.119.04   Driver Version: 450.119.04   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    38W / 250W |   4419MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# bleurt_dataloader=DataLoader(test_dataset,
#                             batch_size=1,
#                             num_workers=2,
#                             shuffle=False)

# %%
from tqdm.notebook import tqdm

fref = open('./corrects.txt', 'w+')
fout = open('./outputs.txt', 'w+')

output=[]
corrects=[]

for batch in tqdm(test_dataloader):
    input_ids=batch["input_ids"].to(device)
    
    outputs = model.generate(input_ids, return_dict_in_generate=True, output_scores=True)
    for i in range(64):
        try:
            outputstring = tokenizer.decode(outputs["sequences"][i], skip_special_tokens=True)

            refstring=batch["sentence"][i].replace('</s>',"")
            output.append(outputstring)
            corrects.append(refstring)

            fref.write(refstring+'\n')
            fout.write(outputstring+'.\n')
        except:
            pass

fref.close()
fout.close()
# Out:
#   0%|          | 0/121 [00:00<?, ?it/s]

# %%
# %%bash
# git clone https://github.com/google-research/language.git language_repo
# cd language_repo
# pip3 install -r language/totto/eval_requirements.txt
# Out:
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.7/site-packages (from -r language/totto/eval_requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: pytest in /opt/conda/lib/python3.7/site-packages (from -r language/totto/eval_requirements.txt (line 2)) (6.2.4)
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from -r language/totto/eval_requirements.txt (line 4)) (1.15.0)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.7/site-packages (from -r language/totto/eval_requirements.txt (line 5)) (0.36.2)
# Requirement already satisfied: importlib-metadata>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->-r language/totto/eval_requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: py>=1.8.2 in /opt/conda/lib/python3.7/site-packages (from pytest->-r language/totto/eval_requirements.txt (line 2)) (1.10.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from pytest->-r language/totto/eval_requirements.txt (line 2)) (20.9)
# Requirement already satisfied: toml in /opt/conda/lib/python3.7/site-packages (from pytest->-r language/totto/eval_requirements.txt (line 2)) (0.10.2)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.7/site-packages (from pytest->-r language/totto/eval_requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.7/site-packages (from pytest->-r language/totto/eval_requirements.txt (line 2)) (21.2.0)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->-r language/totto/eval_requirements.txt (line 2)) (0.13.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest->-r language/totto/eval_requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest->-r language/totto/eval_requirements.txt (line 2)) (3.7.4.3)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.7/site-packages (from sacrebleu->-r language/totto/eval_requirements.txt (line 3)) (1.19.5)
# Requirement already satisfied: portalocker in /opt/conda/lib/python3.7/site-packages (from sacrebleu->-r language/totto/eval_requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: regex in /opt/conda/lib/python3.7/site-packages (from sacrebleu->-r language/totto/eval_requirements.txt (line 3)) (2021.4.4)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.7/site-packages (from sacrebleu->-r language/totto/eval_requirements.txt (line 3)) (0.8.9)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.7/site-packages (from sacrebleu->-r language/totto/eval_requirements.txt (line 3)) (0.4.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->pytest->-r language/totto/eval_requirements.txt (line 2)) (2.4.7)
# Installing collected packages: sacrebleu
# Successfully installed sacrebleu-2.0.0
# Cloning into 'language_repo'...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
# !ls
# Out:
# __notebook__.ipynb  corrects.txt  language_repo  outputs.txt

# %%
# %cd language_repo
# !bash language/totto/totto_eval.sh --prediction_path language/totto/sample/output_sample.txt --target_path language/totto/sample/dev_sample.jsonl
# Out:
# /kaggle/working/language_repo
# Running with the following variables:
# PREDICTION_PATH   : language/totto/sample/output_sample.txt
# TARGET_PATH       : language/totto/sample/dev_sample.jsonl
# BLEURT_CKPT       : unset
# OUTPUT_DIR        : temp
# MODE              : test
# Creating Output directory.
# Cloning moses for BLEU script.
# Cloning into 'temp/mosesdecoder'...
# remote: Enumerating objects: 148070, done.
# remote: Counting objects: 100% (498/498), done.
# remote: Compressing objects: 100% (206/206), done.
# remote: Total 148070 (delta 315), reused 433 (delta 289), pack-reused 147572
# Receiving objects: 100% (148070/148070), 129.86 MiB | 19.84 MiB/s, done.
# Resolving deltas: 100% (114341/114341), done.
# Writing references.
# Writing tables in PARENT format.
# Preparing predictions.
# Writing predictions.
# Running detokenizers.
# ======== EVALUATE OVERALL ========
# Computing BLEU (overall)
# {
#  "name": "BLEU",
#  "score": 45.5,
#  "signature": "nrefs:3|case:mixed|eff:no|tok:13a|smooth:exp|version:2.0.0",
#  "verbose_score": "86.0/63.5/44.7/31.0 (BP = 0.869 ratio = 0.877 hyp_len = 57 ref_len = 65)",
#  "nrefs": "3",
#  "case": "mixed",
#  "eff": "no",
#  "tok": "13a",
#  "smooth": "exp",
#  "version": "2.0.0"
# }
# Computing PARENT (overall)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/opt/conda/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 472, in <module>
#     app.run(main)
#   File "/opt/conda/lib/python3.7/site-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/opt/conda/lib/python3.7/site-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 444, in main
#     references = _text_reference_reader(FLAGS.reference_path)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 120, in _text_reference_reader
#     references0 = _text_reader(multi_reference_paths[0])
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 89, in _text_reader
#     line = _normalize_text(line)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 74, in _normalize_text
#     return tokenize_fn(s.strip().lower())
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 73, in <lambda>
#     tokenize_fn = lambda x: sacrebleu.tokenizers.Tokenizer13a()(x)
# AttributeError: module 'sacrebleu.tokenizers' has no attribute 'Tokenizer13a'
# ======== EVALUATE OVERLAP SUBSET ========
# Computing BLEU (overlap subset)
# {
#  "name": "BLEU",
#  "score": 37.2,
#  "signature": "nrefs:3|case:mixed|eff:no|tok:13a|smooth:exp|version:2.0.0",
#  "verbose_score": "84.8/56.7/37.0/25.0 (BP = 0.809 ratio = 0.825 hyp_len = 33 ref_len = 40)",
#  "nrefs": "3",
#  "case": "mixed",
#  "eff": "no",
#  "tok": "13a",
#  "smooth": "exp",
#  "version": "2.0.0"
# }
# Computing PARENT (overlap subset)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/opt/conda/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 472, in <module>
#     app.run(main)
#   File "/opt/conda/lib/python3.7/site-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/opt/conda/lib/python3.7/site-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 444, in main
#     references = _text_reference_reader(FLAGS.reference_path)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 120, in _text_reference_reader
#     references0 = _text_reader(multi_reference_paths[0])
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 89, in _text_reader
#     line = _normalize_text(line)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 74, in _normalize_text
#     return tokenize_fn(s.strip().lower())
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 73, in <lambda>
#     tokenize_fn = lambda x: sacrebleu.tokenizers.Tokenizer13a()(x)
# AttributeError: module 'sacrebleu.tokenizers' has no attribute 'Tokenizer13a'
# ======== EVALUATE NON-OVERLAP SUBSET ========
# Computing BLEU (non-overlap subset)
# {
#  "name": "BLEU",
#  "score": 58.3,
#  "signature": "nrefs:3|case:mixed|eff:no|tok:13a|smooth:exp|version:2.0.0",
#  "verbose_score": "87.5/72.7/55.0/38.9 (BP = 0.959 ratio = 0.960 hyp_len = 24 ref_len = 25)",
#  "nrefs": "3",
#  "case": "mixed",
#  "eff": "no",
#  "tok": "13a",
#  "smooth": "exp",
#  "version": "2.0.0"
# }
# Computing PARENT (non-overlap subset)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/opt/conda/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 472, in <module>
#     app.run(main)
#   File "/opt/conda/lib/python3.7/site-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/opt/conda/lib/python3.7/site-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 444, in main
#     references = _text_reference_reader(FLAGS.reference_path)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 120, in _text_reference_reader
#     references0 = _text_reader(multi_reference_paths[0])
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 89, in _text_reader
#     line = _normalize_text(line)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 74, in _normalize_text
#     return tokenize_fn(s.strip().lower())
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 73, in <lambda>
#     tokenize_fn = lambda x: sacrebleu.tokenizers.Tokenizer13a()(x)
# AttributeError: module 'sacrebleu.tokenizers' has no attribute 'Tokenizer13a'

# %%
len(output)
# Out:
# 7700

# %%
# !bash language/totto/totto_eval.sh --prediction_path /kaggle/working/outputs.txt --target_path /kaggle/input/table-to-text-generation-dataset-google-totto/totto_data/totto_dev_data.jsonl --output_dir /kaggle/working/
# Out:
# Running with the following variables:
# PREDICTION_PATH   : /kaggle/working/outputs.txt
# TARGET_PATH       : /kaggle/input/table-to-text-generation-dataset-google-totto/totto_data/totto_dev_data.jsonl
# BLEURT_CKPT       : unset
# OUTPUT_DIR        : /kaggle/working
# MODE              : test
# Cloning moses for BLEU script.
# Cloning into '/kaggle/working/mosesdecoder'...
# remote: Enumerating objects: 148070, done.
# remote: Counting objects: 100% (498/498), done.
# remote: Compressing objects: 100% (206/206), done.
# remote: Total 148070 (delta 315), reused 433 (delta 289), pack-reused 147572
# Receiving objects: 100% (148070/148070), 129.86 MiB | 22.12 MiB/s, done.
# Resolving deltas: 100% (114341/114341), done.
# Writing references.
# Writing tables in PARENT format.
# Preparing predictions.
# Writing predictions.
# Running detokenizers.
# ======== EVALUATE OVERALL ========
# Computing BLEU (overall)
# {
#  "name": "BLEU",
#  "score": 32.6,
#  "signature": "nrefs:3|case:mixed|eff:no|tok:13a|smooth:exp|version:2.0.0",
#  "verbose_score": "69.8/42.2/30.0/22.2 (BP = 0.870 ratio = 0.878 hyp_len = 111456 ref_len = 126951)",
#  "nrefs": "3",
#  "case": "mixed",
#  "eff": "no",
#  "tok": "13a",
#  "smooth": "exp",
#  "version": "2.0.0"
# }
# Computing PARENT (overall)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/opt/conda/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 472, in <module>
#     app.run(main)
#   File "/opt/conda/lib/python3.7/site-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/opt/conda/lib/python3.7/site-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 444, in main
#     references = _text_reference_reader(FLAGS.reference_path)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 120, in _text_reference_reader
#     references0 = _text_reader(multi_reference_paths[0])
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 89, in _text_reader
#     line = _normalize_text(line)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 74, in _normalize_text
#     return tokenize_fn(s.strip().lower())
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 73, in <lambda>
#     tokenize_fn = lambda x: sacrebleu.tokenizers.Tokenizer13a()(x)
# AttributeError: module 'sacrebleu.tokenizers' has no attribute 'Tokenizer13a'
# ======== EVALUATE OVERLAP SUBSET ========
# Computing BLEU (overlap subset)
# {
#  "name": "BLEU",
#  "score": 37.6,
#  "signature": "nrefs:3|case:mixed|eff:no|tok:13a|smooth:exp|version:2.0.0",
#  "verbose_score": "72.7/47.2/35.6/27.5 (BP = 0.879 ratio = 0.886 hyp_len = 55163 ref_len = 62285)",
#  "nrefs": "3",
#  "case": "mixed",
#  "eff": "no",
#  "tok": "13a",
#  "smooth": "exp",
#  "version": "2.0.0"
# }
# Computing PARENT (overlap subset)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/opt/conda/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 472, in <module>
#     app.run(main)
#   File "/opt/conda/lib/python3.7/site-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/opt/conda/lib/python3.7/site-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 444, in main
#     references = _text_reference_reader(FLAGS.reference_path)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 120, in _text_reference_reader
#     references0 = _text_reader(multi_reference_paths[0])
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 89, in _text_reader
#     line = _normalize_text(line)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 74, in _normalize_text
#     return tokenize_fn(s.strip().lower())
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 73, in <lambda>
#     tokenize_fn = lambda x: sacrebleu.tokenizers.Tokenizer13a()(x)
# AttributeError: module 'sacrebleu.tokenizers' has no attribute 'Tokenizer13a'
# ======== EVALUATE NON-OVERLAP SUBSET ========
# Computing BLEU (non-overlap subset)
# {
#  "name": "BLEU",
#  "score": 27.5,
#  "signature": "nrefs:3|case:mixed|eff:no|tok:13a|smooth:exp|version:2.0.0",
#  "verbose_score": "66.9/37.4/24.6/16.9 (BP = 0.862 ratio = 0.871 hyp_len = 56293 ref_len = 64666)",
#  "nrefs": "3",
#  "case": "mixed",
#  "eff": "no",
#  "tok": "13a",
#  "smooth": "exp",
#  "version": "2.0.0"
# }
# Computing PARENT (non-overlap subset)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/opt/conda/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 472, in <module>
#     app.run(main)
#   File "/opt/conda/lib/python3.7/site-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/opt/conda/lib/python3.7/site-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 444, in main
#     references = _text_reference_reader(FLAGS.reference_path)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 120, in _text_reference_reader
#     references0 = _text_reader(multi_reference_paths[0])
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 89, in _text_reader
#     line = _normalize_text(line)
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 74, in _normalize_text
#     return tokenize_fn(s.strip().lower())
#   File "/kaggle/working/language_repo/language/totto/totto_parent_eval.py", line 73, in <lambda>
#     tokenize_fn = lambda x: sacrebleu.tokenizers.Tokenizer13a()(x)
# AttributeError: module 'sacrebleu.tokenizers' has no attribute 'Tokenizer13a'
